# %% [markdown]
# <a href="https://colab.research.google.com/github/dmahakal2006/AI-Job-Description-git-clone-https-github.com-username-project/blob/main/DM%20PROJECT%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("/content/sample_data/amazon.csv")
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# Data Cleaning + Analysis Code

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset already loaded
# data = pd.read_csv("amazon.csv")

# 1. Dataset Size
print("Shape:", data.shape)

# 2. Column Names
print("Columns:", data.columns)

# 3. Missing Values Check
print("Missing Values:\n", data.isnull().sum())

# 4. Remove Missing Values
data = data.dropna()

# 5. Remove Duplicate Rows
data = data.drop_duplicates()
# Convert price columns to numeric by removing '₹' and ',' if they are still strings
if data['actual_price'].dtype == 'object':
    data['actual_price'] = data['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)
if data['discounted_price'].dtype == 'object':
    data['discounted_price'] = data['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
# Out:
# Shape: (1463, 18)
# Columns: Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'discount_percent',
#        'fake_discount'],
#       dtype='object')
# Missing Values:
#  product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# discount_percent       0
# fake_discount          0
# dtype: int64

# %% [markdown]
# Data Cleaning

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# discount_percent       0
# fake_discount          0
# dtype: int64

# %% [markdown]
# Discount % calculate

# %%
data["Discount%"] = ((data["actual_price"] - data["discounted_price"]) / data["actual_price"]) * 100

data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price discount_percentage  rating rating_count  \
# 0        1099.0                 64%     4.2       24,269
# ...

# %%
data[['actual_price', 'discounted_price', 'Discount%']].head()
# Out:
#    actual_price  discounted_price  Discount%
# 0        1099.0             399.0  63.694268
# 1         349.0             199.0  42.979943
# 2        1899.0             199.0  89.520800
# 3         699.0             329.0  52.932761
# 4         399.0             154.0  61.403509

# %% [markdown]
# Features Select

# %%
X = data[['actual_price', 'discounted_price', 'Discount%']]
X.head()
# Out:
#    actual_price  discounted_price  Discount%
# 0        1099.0             399.0  63.694268
# 1         349.0             199.0  42.979943
# 2        1899.0             199.0  89.520800
# 3         699.0             329.0  52.932761
# 4         399.0             154.0  61.403509

# %% [markdown]
# Scaling

# %%
pd.DataFrame(X_scaled, columns=["OriginalPrice", "DiscountPrice", "Discount%"]).head()
# Out:
#    OriginalPrice  DiscountPrice  Discount%
# 0      -0.400106      -0.393080   0.742543
# 1      -0.469057      -0.421875  -0.215780
# 2      -0.326558      -0.421875   1.937376
# 3      -0.436879      -0.403158   0.244675
# 4      -0.464460      -0.428353   0.636564

# %% [markdown]
# Algorithm (K-Means Clustering)

# %%
data.head()
data["Cluster"].value_counts()
# Out:
# Cluster
# 0    832
# 1    528
# 2    103
# Name: count, dtype: int64

# %% [markdown]
# Cluster meaning explain
#
#
# Cluster 0 → Normal discount
#
#
# Cluster 1 → High discount
# (suspicious)
#
#
# Cluster 2 → Fake pattern

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
data["Cluster"] = kmeans.fit_predict(X_scaled)
data.head()
data["Cluster"].value_counts()
# Out:
# Cluster
# 0    832
# 1    528
# 2    103
# Name: count, dtype: int64

# %% [markdown]
# Graph

# %%
import matplotlib.pyplot as plt

plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=data["Cluster"])
plt.title("Dark Pattern Clustering")
plt.xlabel("Scaled Original Price")
plt.ylabel("Scaled Discount Price")
plt.show()
